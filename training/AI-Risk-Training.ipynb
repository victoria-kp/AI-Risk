# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/AI-Risk-Training/AI-Risk
# Out:
# /content/drive/MyDrive/AI-Risk-Training/AI-Risk

# %%
# !pip install "trl==0.14.0" --no-deps
# !pip install peft datasets bitsandbytes
# !pip install vllm

# %%
# !python analysis/run_benchmark.py --games 20 --model Qwen/Qwen2.5-7B-Instruct --output results/qwen_base_benchmark
# Out:
# Game 1/20 (seed=42)... 2026-03-30 23:22:06.950495: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-30 23:22:06.963275: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774912926.979208   96962 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774912926.984377   96962 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python training/train_sft.py --max-steps 1000 --save-steps 200 --eval-steps 50
# Out:
# === SFT Training for Risk [GPU] ===
# Model:        Qwen/Qwen2.5-7B-Instruct
# Data:         data/hybrid_data/turns.jsonl
# Output:       ./risk_sft_output
# Max steps:    1000
# LR:           2e-05
#
# Loading model...
# 2026-03-30 17:38:20.099441: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-30 17:38:20.111239: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774892300.126375    6947 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python analysis/run_benchmark.py --games 20 --model ./risk_sft_output/checkpoint-200 --output results/qwen_sft_benchmark
# Out:
# Game 1/20 (seed=42)... 2026-03-31 00:20:33.517124: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-31 00:20:33.530075: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774916433.545275  111667 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774916433.550145  111667 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python training/train_grpo.py --resume-from ./risk_sft_output/checkpoint-200 --max-steps 50 --save-steps 10 --learning-rate 1e-6
# Out:
# === GRPO Training for Risk [GPU] ===
# Model:        Qwen/Qwen2.5-7B-Instruct
# Resume from:  ./risk_sft_output/checkpoint-200
# Data:         data/hybrid_data/turns.jsonl
# Output:       ./risk_grpo_output
# Max steps:    50
# Generations:  4
# LR:           1e-06
#
# Loading model...
# 2026-03-30 19:04:05.900402: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-30 19:04:05.913142: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python analysis/run_benchmark.py --games 20 --model ./risk_grpo_output --output results/qwen_grpo_v2_benchmark
# Out:
# Game 1/20 (seed=42)... 2026-03-31 01:05:18.037440: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-31 01:05:18.050912: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774919118.067476  123131 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774919118.072632  123131 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python training/train_grpo.py --resume-from ./risk_grpo_output --data data/hybrid_data/turns.jsonl results/qwen_grpo_v2_benchmark/turns.jsonl --output-dir ./risk_grpo_v3 --max-steps 50 --learning-rate 1e-6 --save-steps 10
# Out:
# === GRPO Training for Risk [GPU] ===
# Model:        Qwen/Qwen2.5-7B-Instruct
# Resume from:  ./risk_grpo_output
# Data:         data/hybrid_data/turns.jsonl, results/qwen_grpo_v2_benchmark/turns.jsonl
# Output:       ./risk_grpo_v3
# Max steps:    50
# Generations:  4
# LR:           1e-06
#
# Loading model...
# 2026-03-31 02:02:09.264826: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-31 02:02:09.277617: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python analysis/run_benchmark.py --games 20 --model ./risk_grpo_v3 --output results/grpo_v3_benchmark
# Out:
# Game 1/20 (seed=42)... 2026-03-31 02:24:51.960302: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-31 02:24:51.973533: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774923891.990486  144360 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774923891.995927  144360 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
